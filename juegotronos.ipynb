# %% [markdown]
# Importamos pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('data/got.csv')
df.head(10)
# Out:
#                name     allegiance  season  episode         location  \
# 0      Waymar Royce  Night's Watch       1        1  Beyond the Wall
# 1             Gared  Night's Watch       1        1  Beyond the Wall
# 2              Will  Night's Watch       1        1       Winterfell
# 3              Stag            NaN       1        1       Winterfell
# 4          Direwolf            NaN       1        1       Winterfell
# 5         Jon Arryn    House Arryn       1        1   King's Landing
# 6      Dothraki man       Dothraki       1        1           Pentos
# 7  Catspaw assassin            NaN       1        2       Winterfell
# 8             Mycah      Smallfolk       1        2        Kingsroad
# 9              Lady    House Stark       1        2        Kingsroad
#
#                        killer    killers_house     method  death_no
# 0                White Walker              NaN  Ice sword         1
# 1                White Walker              NaN  Ice sword         2
# ...

# %% [markdown]
# Agrupamos el Dataframe por asesino

# %%
df_killer = df.groupby('killer')['death_no'].agg(['count'])
df_killer
# Out:
#                  count
# killer
# Accident             1
# Aemon Targaryen      1
# Alliser Thorne       3
# Amory Lorch          1
# Arthur Dayne         3
# ...                ...
# Wildling giant       2
# Wun Wun              3
# Yara Greyjoy        11
# Ygritte             14
# Yoren                5
#
# [128 rows x 1 columns]

# %% [markdown]
# Quiero mostrar un gráfico con los primeros 5 asesinos
# Es necesario una librería llamada matplotlib

# %%
df_primeros = df_killer.head(5)
df_primeros.groupby('killer').sum().plot(kind='pie', y='count')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Vamos a separar estos datos por temporada
# Para generar gráficos con los primeros asesinos por temporada

# %%
df_season = df[ df['season'] == 4]
df_season.to_csv('data/got4.csv')
df_season
# Out:
#                                     name                         allegiance  \
# 274  Baratheon of King's Landing soldier  House Baratheon of King's Landing
# 275              Lowell (King's Soldier)  House Baratheon of King's Landing
# 276  Baratheon of King's Landing soldier  House Baratheon of King's Landing
# 277  Baratheon of King's Landing soldier  House Baratheon of King's Landing
# 278                             Polliver  House Baratheon of King's Landing
# ..                                   ...                                ...
# 439                                Zalla                          Smallfolk
# 440                           Jojen Reed                        House Stark
# 441           Sandor "The Hound" Clegane                      House Clegane
# 442                                 Shae                    House Lannister
# 443                      Tywin Lannister                    House Lannister
#
# ...
